# %%
from bokeh.plotting import figure, show, output_notebook, gmap
from bokeh.tile_providers import CARTODBPOSITRON, CARTODBPOSITRON_RETINA
from bokeh.transform import factor_cmap
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.palettes import Spectral6
from bokeh.io import output_file
import pandas as pd
import numpy as np
import math
from ast import literal_eval

# %%
coords = [[-38.7, 122], [-38, 121], [-37.8, 122.27], [-37.5, 122.33], [-37.8, 122.1], [-38.7, 123.4], [-40.1, 122], [-38.2, 123.1],
          [-37, 120.5]]

cls = [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
import math

def merc(Coords):
    new_locs = []
    for co in Coords:
        lat = co[0]
        lon = co[1]

        r_major = 6378137.000
        x = r_major * math.radians(lon)
        scale = x/lon
        y = 180.0/math.pi * math.log(math.tan(math.pi/4.0 + 
            lat * (math.pi/180.0)/2.0)) * scale
        new_locs.append((-x,-y ))
    return new_locs

# %%
locs = merc(coords)

# %%
locs
# Out:
# [(-13580977.876779376, 4678789.796625015),
#  (-13469658.385986103, 4579425.812870099),
#  (-13611034.139293559, 4551210.9196918905),
#  (-13617713.308741156, 4509031.393076654),
#  (-13592109.825858701, 4551210.9196918905),
#  (-13736825.16388996, 4678789.796625015),
#  (-13580977.876779376, 4880484.665662283),
#  (-13703429.316651976, 4607717.759142002),
#  (-13413998.640589466, 4439106.787250587)]

# %%
df = pd.DataFrame(locs, columns = ["x", "y"])

# %%
df['class'] = cls
df['size'] = [13, 9, 9, 11, 30, 5, 8, 17, 11]

# %%
df.head()
# Out:
#               x             y  class  size
# 0 -1.358098e+07  4.678790e+06      1    13
# 1 -1.346966e+07  4.579426e+06      2     9
# 2 -1.361103e+07  4.551211e+06      3     9
# 3 -1.361771e+07  4.509031e+06      1    11
# 4 -1.359211e+07  4.551211e+06      2    30

# %%
p = figure(x_range=(-13622668.36, -13577662.23), y_range=(4463875.10, 4694478.89),
           x_axis_type="mercator", y_axis_type="mercator", )
p.add_tile(CARTODBPOSITRON)
# Out:
# TileRenderer(id='1085', ...)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1089">Loading BokehJS ...</span>
#     </div>

# %%
show(p)
# Out:
#   <div class="bk-root" id="60b8aff4-672b-4b51-8ad3-3ca7583201c4" data-root-id="1045"></div>

# %%
p = figure(x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(CARTODBPOSITRON_RETINA)

group_1 = df[df['class'] == 1]
group_2 = df[df['class'] == 2]
group_3 = df[df['class'] == 3]

g1_source = ColumnDataSource(group_1)
g2_source = ColumnDataSource(group_2)
g3_source = ColumnDataSource(group_3)


p.circle(x = 'x',
         y = 'y', size = 'size', color="#1f78b4",
         legend = 'one', source=g1_source)
p.circle(x = 'x',
         y = 'y', size = 'size', color="#d93b43",
         legend = 'two', source=g2_source)
p.circle(x = 'x',
         y = 'y', size = 'size', color="#599d7A",
         legend = 'three', source=g3_source)

output_notebook()
output_file('map1.html')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1388">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="144a8dad-0938-447d-b6da-f2488fa4f662" data-root-id="1295"></div>

# %%
map_options = GMapOptions(lat=-13580977.876779376, lng=4678789.796625015, map_type="roadmap", zoom=11)


p = gmap("AIzaSyAQXxdt2MmghmhCL03eJ0E2Yw2JRsNsyBg", map_options, title="San Francisco")

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2290">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a2061230-598e-430a-a66d-43770dd303c3" data-root-id="2264"></div>

# %%
output_file("gmap.html")

map_options = GMapOptions(lat=30.2861, lng=-97.7394, map_type="roadmap", zoom=11)

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
p = gmap("GOOGLE_API_KEY", map_options, title="Austin")

source = ColumnDataSource(
    data=dict(lat=[ 30.29,  30.20,  30.29],
              lon=[-97.70, -97.74, -97.78])
)

p.circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, source=source)

show(p)
# Out:
#   <div class="bk-root" id="6982aef2-3dcd-4332-a668-e950408a7761" data-root-id="2580"></div>
